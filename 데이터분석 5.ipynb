# %%
import re
tel_num = "0101112222 gildon@abc.com"
# 글자 처음부터 찾기
m = re.match(pattern = '\d\d\d\d\d\d\d\d\d\d', string=tel_num)
print(type(m))
print(m)
# Out:
# <class 're.Match'>
# <re.Match object; span=(0, 10), match='0101112222'>

# %%
tel_num = "홍길동 0101112222 gildon@abc.com"

# m = re.search(pattern = '\d\d\d\d\d\d\d\d\d\d', string=tel_num)
# m = re.search(pattern = '\d{10}', string=tel_num)
m = re.search(pattern = '\d{3}-?\d{3}-?\d{4}', string=tel_num)

print(type(m))
print(m)
# Out:
# <class 're.Match'>
# <re.Match object; span=(4, 14), match='0101112222'>

# %%
tele_num_space_paren_dash = '(123) 456-7890'

p = '\(?\d{3}\)?\s?\d{3}\s?-?\d{4}'

m = re.match(pattern=p, string=tele_num_space_paren_dash)

print(m)
# Out:
# <re.Match object; span=(0, 14), match='(123) 456-7890'>
