# %%
#데이터 로딩
import pandas as pd
df = pd.read_csv('./data/gapminder.tsv',sep='\t')

# %%
#행과 열
df.shape
# Out:
# (1704, 6)

# %%
#데이더 구조
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1704 entries, 0 to 1703
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   country    1704 non-null   object
#  1   continent  1704 non-null   object
#  2   year       1704 non-null   int64
#  3   lifeExp    1704 non-null   float64
#  4   pop        1704 non-null   int64
#  5   gdpPercap  1704 non-null   float64
# dtypes: float64(2), int64(2), object(2)
# memory usage: 80.0+ KB

# %%
# d데이터 types타입들
df.dtypes
# Out:
# country       object
# continent     object
# year           int64
# lifeExp      float64
# pop            int64
# gdpPercap    float64
# dtype: object

# %%
#기초통계량
df.describe(include="object") #글자만 추출
# count - 총갯수
# unique - 유일한 값 갯수
# top - 최빈값(가장 많이 보이는 값)
# freq - 최빈도수(최빈값이 보이는 횟수)
# Out:
#             country continent
# count          1704      1704
# unique          142         5
# top     Afghanistan    Africa
# freq             12       624

# %%
# 칼럼이름 추출
df.columns
# Out:
# Index(['country', 'continent', 'year', 'lifeExp', 'pop', 'gdpPercap'], dtype='object')

# %%
df[['country','pop']] #여러개 칼럼은 리스트로 묶기
# Out:
#           country       pop
# 0     Afghanistan   8425333
# 1     Afghanistan   9240934
# 2     Afghanistan  10267083
# 3     Afghanistan  11537966
# 4     Afghanistan  13079460
# ...           ...       ...
# 1699     Zimbabwe   9216418
# 1700     Zimbabwe  10704340
# 1701     Zimbabwe  11404948
# 1702     Zimbabwe  11926563
# 1703     Zimbabwe  12311143
#
# [1704 rows x 2 columns]

# %%
df[ 3:5 ]
df.loc[ [5,4,3,2,1] ][ 1:3 ] # 여러개, 리스트 필수. 앞 리스트의 1부터 3미만까지의 값 추출
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138

# %%
df[ 'year' ] < 1960 
#벡터 연산(브로드캐스팅)
# 시리즈, 연산자의 값 - 시리즈내 모든 항목에 연산적용, 결과를 시리즈로 반환
# Out:
# 0        True
# 1        True
# 2       False
# 3       False
# 4       False
#         ...
# 1699    False
# 1700    False
# 1701    False
# 1702    False
# 1703    False
# Name: year, Length: 1704, dtype: bool

# %%
b1 = df[ 'year' ] < 1960 
df [b1] #True에 해당하는 행만 추출
# Out:
#           country continent  year  lifeExp      pop    gdpPercap
# 0     Afghanistan      Asia  1952   28.801  8425333   779.445314
# 1     Afghanistan      Asia  1957   30.332  9240934   820.853030
# 12        Albania    Europe  1952   55.230  1282697  1601.056136
# 13        Albania    Europe  1957   59.280  1476505  1942.284244
# 24        Algeria    Africa  1952   43.077  9279525  2449.008185
# ...           ...       ...   ...      ...      ...          ...
# 1669  Yemen, Rep.      Asia  1957   33.970  5498090   804.830455
# 1680       Zambia    Africa  1952   42.038  2672000  1147.388831
# 1681       Zambia    Africa  1957   44.077  3016000  1311.956766
# 1692     Zimbabwe    Africa  1952   48.451  3080907   406.884115
# 1693     Zimbabwe    Africa  1957   50.469  3646340   518.764268
#
# [284 rows x 6 columns]

# %%
df.loc[[2,4,6]]
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106
# 6  Afghanistan      Asia  1982   39.854  12881816  978.011439

# %%
print(df.loc[2,'year']) #행과 열의 교차되는 지점(셀)의 값
# Out:
# 1962

# %%
df2 = df.copy() #복사

# %%
df2
# Out:
#           country continent  year  lifeExp       pop   gdpPercap
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2     Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106
# ...           ...       ...   ...      ...       ...         ...
# 1699     Zimbabwe    Africa  1987   62.351   9216418  706.157306
# 1700     Zimbabwe    Africa  1992   60.377  10704340  693.420786
# 1701     Zimbabwe    Africa  1997   46.809  11404948  792.449960
# 1702     Zimbabwe    Africa  2002   39.989  11926563  672.038623
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298
#
# [1704 rows x 6 columns]

# %%
b1 = df['country'] == 'Afghanistan'
df3 = df2[ b1 ] #True
df3
# Out:
#         country continent  year  lifeExp       pop   gdpPercap
# 0   Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1   Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2   Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3   Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4   Afghanistan      Asia  1972   36.088  13079460  739.981106
# 5   Afghanistan      Asia  1977   38.438  14880372  786.113360
# 6   Afghanistan      Asia  1982   39.854  12881816  978.011439
# 7   Afghanistan      Asia  1987   40.822  13867957  852.395945
# 8   Afghanistan      Asia  1992   41.674  16317921  649.341395
# 9   Afghanistan      Asia  1997   41.763  22227415  635.341351
# 10  Afghanistan      Asia  2002   42.129  25268405  726.734055
# 11  Afghanistan      Asia  2007   43.828  31889923  974.580338

# %%
df2.index
# Out:
# RangeIndex(start=0, stop=1704, step=1)

# %%
df2.index = df2['country']

# %%
df2.index
# Out:
# Index(['Afghanistan', 'Afghanistan', 'Afghanistan', 'Afghanistan',
#        'Afghanistan', 'Afghanistan', 'Afghanistan', 'Afghanistan',
#        'Afghanistan', 'Afghanistan',
#        ...
#        'Zimbabwe', 'Zimbabwe', 'Zimbabwe', 'Zimbabwe', 'Zimbabwe', 'Zimbabwe',
#        'Zimbabwe', 'Zimbabwe', 'Zimbabwe', 'Zimbabwe'],
#       dtype='object', name='country', length=1704)

# %%
df2
# Out:
#                  country continent  year  lifeExp       pop   gdpPercap
# country
# Afghanistan  Afghanistan      Asia  1952   28.801   8425333  779.445314
# Afghanistan  Afghanistan      Asia  1957   30.332   9240934  820.853030
# Afghanistan  Afghanistan      Asia  1962   31.997  10267083  853.100710
# Afghanistan  Afghanistan      Asia  1967   34.020  11537966  836.197138
# Afghanistan  Afghanistan      Asia  1972   36.088  13079460  739.981106
# ...                  ...       ...   ...      ...       ...         ...
# Zimbabwe        Zimbabwe    Africa  1987   62.351   9216418  706.157306
# Zimbabwe        Zimbabwe    Africa  1992   60.377  10704340  693.420786
# Zimbabwe        Zimbabwe    Africa  1997   46.809  11404948  792.449960
# Zimbabwe        Zimbabwe    Africa  2002   39.989  11926563  672.038623
# Zimbabwe        Zimbabwe    Africa  2007   43.487  12311143  469.709298
#
# [1704 rows x 6 columns]

# %%
df2.loc['Afghanistan']
# Out:
#                  country continent  year  lifeExp       pop   gdpPercap
# country
# Afghanistan  Afghanistan      Asia  1952   28.801   8425333  779.445314
# Afghanistan  Afghanistan      Asia  1957   30.332   9240934  820.853030
# Afghanistan  Afghanistan      Asia  1962   31.997  10267083  853.100710
# Afghanistan  Afghanistan      Asia  1967   34.020  11537966  836.197138
# Afghanistan  Afghanistan      Asia  1972   36.088  13079460  739.981106
# Afghanistan  Afghanistan      Asia  1977   38.438  14880372  786.113360
# Afghanistan  Afghanistan      Asia  1982   39.854  12881816  978.011439
# Afghanistan  Afghanistan      Asia  1987   40.822  13867957  852.395945
# Afghanistan  Afghanistan      Asia  1992   41.674  16317921  649.341395
# Afghanistan  Afghanistan      Asia  1997   41.763  22227415  635.341351
# Afghanistan  Afghanistan      Asia  2002   42.129  25268405  726.734055
# Afghanistan  Afghanistan      Asia  2007   43.828  31889923  974.580338

# %%
# df.groupby('칼럼명')['통계 낼 칼럼명'].통계함수()
# 연도별 평균 예상수명(lifeExp)
ans = df.groupby('year')['lifeExp'].mean()
ans
# Out:
# year
# 1952    49.057620
# 1957    51.507401
# 1962    53.609249
# 1967    55.678290
# 1972    57.647386
# 1977    59.570157
# 1982    61.533197
# 1987    63.212613
# 1992    64.160338
# 1997    65.014676
# 2002    65.694923
# 2007    67.007423
# Name: lifeExp, dtype: float64

# %%
ans = df.groupby('year')['lifeExp'].max()
ans
# Out:
# year
# 1952    72.670
# 1957    73.470
# 1962    73.680
# 1967    74.160
# 1972    74.720
# 1977    76.110
# 1982    77.110
# 1987    78.670
# 1992    79.360
# 1997    80.690
# 2002    82.000
# 2007    82.603
# Name: lifeExp, dtype: float64

# %%
ans = df.groupby('year')['lifeExp'].count() #어떤 칼럼을 대든 갯수가 동일하게 나타남
ans
# Out:
# year
# 1952    142
# 1957    142
# 1962    142
# 1967    142
# 1972    142
# 1977    142
# 1982    142
# 1987    142
# 1992    142
# 1997    142
# 2002    142
# 2007    142
# Name: lifeExp, dtype: int64

# %%
df['country'].unique()
df['country'].value_counts() #나라의 갯수
# Out:
# country
# Afghanistan          12
# Pakistan             12
# New Zealand          12
# Nicaragua            12
# Niger                12
#                      ..
# Eritrea              12
# Equatorial Guinea    12
# El Salvador          12
# Egypt                12
# Zimbabwe             12
# Name: count, Length: 142, dtype: int64

# %%
print(df.groupby('year'))

# %%
ans = df.groupby(['year','continent'])[['lifeExp','gdpPercap']].mean()
ans
# Out:
#                   lifeExp     gdpPercap
# year continent
# 1952 Africa     39.135500   1252.572466
#      Americas   53.279840   4079.062552
#      Asia       46.314394   5195.484004
#      Europe     64.408500   5661.057435
#      Oceania    69.255000  10298.085650
# 1957 Africa     41.266346   1385.236062
#      Americas   55.960280   4616.043733
#      Asia       49.318544   5787.732940
#      Europe     66.703067   6963.012816
#      Oceania    70.295000  11598.522455
# 1962 Africa     43.319442   1598.078825
#      Americas   58.398760   4901.541870
#      Asia       51.563223   5729.369625
#      Europe     68.539233   8365.486814
#      Oceania    71.085000  12696.452430
# 1967 Africa     45.334538   2050.363801
#      Americas   60.410920   5668.253496
#      Asia       54.663640   5971.173374
#      Europe     69.737600  10143.823757
#      Oceania    71.310000  14495.021790
# 1972 Africa     47.450942   2339.615674
#      Americas   62.394920   6491.334139
# ...

# %%
ans.loc[1952,'Asia'] #멀티인덱스
# Out:
# lifeExp        46.314394
# gdpPercap    5195.484004
# Name: (1952, Asia), dtype: float64

# %%
ans.reset_index()
# Out:
#     year continent    lifeExp     gdpPercap
# 0   1952    Africa  39.135500   1252.572466
# 1   1952  Americas  53.279840   4079.062552
# 2   1952      Asia  46.314394   5195.484004
# 3   1952    Europe  64.408500   5661.057435
# 4   1952   Oceania  69.255000  10298.085650
# 5   1957    Africa  41.266346   1385.236062
# 6   1957  Americas  55.960280   4616.043733
# 7   1957      Asia  49.318544   5787.732940
# 8   1957    Europe  66.703067   6963.012816
# 9   1957   Oceania  70.295000  11598.522455
# 10  1962    Africa  43.319442   1598.078825
# 11  1962  Americas  58.398760   4901.541870
# 12  1962      Asia  51.563223   5729.369625
# 13  1962    Europe  68.539233   8365.486814
# 14  1962   Oceania  71.085000  12696.452430
# 15  1967    Africa  45.334538   2050.363801
# 16  1967  Americas  60.410920   5668.253496
# 17  1967      Asia  54.663640   5971.173374
# 18  1967    Europe  69.737600  10143.823757
# 19  1967   Oceania  71.310000  14495.021790
# ...

# %%
# 대륙별 나라갯수
df.groupby('continent')['country'].nunique() #혹은 count(),value_counts() <-얘는 대륙-나라도 다 나옴
# Out:
# continent
# Africa      52
# Americas    25
# Asia        33
# Europe      30
# Oceania      2
# Name: country, dtype: int64

# %%
#연도별 평균 기대수명
df.groupby('year')['lifeExp'].mean()
# Out:
# year
# 1952    49.057620
# 1957    51.507401
# 1962    53.609249
# 1967    55.678290
# 1972    57.647386
# 1977    59.570157
# 1982    61.533197
# 1987    63.212613
# 1992    64.160338
# 1997    65.014676
# 2002    65.694923
# 2007    67.007423
# Name: lifeExp, dtype: float64

# %%
df.groupby('year')['lifeExp'].mean().plot()
# Out:
# <Axes: xlabel='year'>

# %%
df.groupby('year')['lifeExp'].mean().plot.bar() #바가 생김
# Out:
# <Axes: xlabel='year'>

# %%
#한국의 연도별 기대수명
b1 = df['country'] == 'Korea, Rep.'
df[b1]
# Out:
#          country continent  year  lifeExp       pop     gdpPercap
# 840  Korea, Rep.      Asia  1952   47.453  20947571   1030.592226
# 841  Korea, Rep.      Asia  1957   52.681  22611552   1487.593537
# 842  Korea, Rep.      Asia  1962   55.292  26420307   1536.344387
# 843  Korea, Rep.      Asia  1967   57.716  30131000   2029.228142
# 844  Korea, Rep.      Asia  1972   62.612  33505000   3030.876650
# 845  Korea, Rep.      Asia  1977   64.766  36436000   4657.221020
# 846  Korea, Rep.      Asia  1982   67.123  39326000   5622.942464
# 847  Korea, Rep.      Asia  1987   69.810  41622000   8533.088805
# 848  Korea, Rep.      Asia  1992   72.244  43805450  12104.278720
# 849  Korea, Rep.      Asia  1997   74.647  46173816  15993.527960
# 850  Korea, Rep.      Asia  2002   77.045  47969150  19233.988180
# 851  Korea, Rep.      Asia  2007   78.623  49044790  23348.139730

# %%
#한국의 연도별 기대수명을 그래프로
b1 = df['country'] == 'Korea, Rep.'
df[b1].plot(x='year', y='lifeExp', kind='bar') #혹은 line
# b2 = df.groupby('country')['lifeExp'].mean().plot()
# Out:
# <Axes: xlabel='year'>

# %%
import pandas as pd
s1 = pd.Series(data=[33,42], index=['홍','김'])
s1.index='홍,김'.split(',')
s1
# Out:
# 홍    33
# 김    42
# dtype: int64

# %%
s1['홍']
# Out:
# np.int64(33)

# %%
scientists = pd.DataFrame({
    "Name": ["Rosaline Franklin", "William Gosset"],
    "Occupation": ["Chemist", "Statistician"],
    "Born": ["1920-07-25", "1876-06-13"],
    "Died": ["1958-04-16", "1937-10-16"],
    "Age": [37, 61],
})
print(scientists)
# Out:
#                 Name    Occupation        Born        Died  Age
# 0  Rosaline Franklin       Chemist  1920-07-25  1958-04-16   37
# 1     William Gosset  Statistician  1876-06-13  1937-10-16   61

# %%
scientists = pd.DataFrame(
    data={
        "Occupation": ["Chemist", "Statistician"],
        "Born": ["1920-07-25", "1876-06-13"],
        "Died": ["1958-04-16", "1937-10-16"],
        "Age": [37, 61],
    },
    index=["Rosaline Franklin", "William Gosset"],
    columns=["Occupation", "Born", "Died", "Age"],
)
print(scientists)
# Out:
#                      Occupation        Born        Died  Age
# Rosaline Franklin       Chemist  1920-07-25  1958-04-16   37
# William Gosset     Statistician  1876-06-13  1937-10-16   61

# %%
first_row = scientists.loc['William Gosset'] #행 추출할 때 .loc 필수
first_row
# Out:
# Occupation    Statistician
# Born            1876-06-13
# Died            1937-10-16
# Age                     61
# Name: William Gosset, dtype: object

# %%
first_row.index #왼쪽, 기준이 되는 세로줄
# Out:
# Index(['Occupation', 'Born', 'Died', 'Age'], dtype='object')

# %%
first_row.values #오른쪽, 개체들
# Out:
# array(['Statistician', '1876-06-13', '1937-10-16', np.int64(61)],
#       dtype=object)

# %%
scientists.T #인덱스와 밸류 위치를 바꿈
# Out:
#            Rosaline Franklin William Gosset
# Occupation           Chemist   Statistician
# Born              1920-07-25     1876-06-13
# Died              1958-04-16     1937-10-16
# Age                       37             61

# %%
scientists = pd.read_csv("./data/scientists.csv")
scientists
# Out:
#                    Name        Born        Died  Age          Occupation
# 0     Rosaline Franklin  1920-07-25  1958-04-16   37             Chemist
# 1        William Gosset  1876-06-13  1937-10-16   61        Statistician
# 2  Florence Nightingale  1820-05-12  1910-08-13   90               Nurse
# 3           Marie Curie  1867-11-07  1934-07-04   66             Chemist
# 4         Rachel Carson  1907-05-27  1964-04-14   56           Biologist
# 5             John Snow  1813-03-15  1858-06-16   45           Physician
# 6           Alan Turing  1912-06-23  1954-06-07   41  Computer Scientist
# 7          Johann Gauss  1777-04-30  1855-02-23   77       Mathematician

# %%
ages = scientists['Age']
b1 = ages > ages.mean() #데이터프레임:진실/거짓값 다 나옴
print('mean=', ages.mean())
ages[ b1 ] #평균보다 큰 값만 출력 + True값만
# len(ages[b1]) #위의 갯수
# Out:
# mean= 59.125
# 1    61
# 2    90
# 3    66
# 7    77
# Name: Age, dtype: int64

# %%
ages + pd.Series([1,2])
# Out:
# 0    38.0
# 1    63.0
# 2     NaN
# 3     NaN
# 4     NaN
# 5     NaN
# 6     NaN
# 7     NaN
# dtype: float64
