# %%
import pandas as pd
import matplotlib.pyplot as plt
plt.rc('font', family='Malgun Gothic')

file = './data/서울시 휴게음식점 인허가 정보.csv'
df = pd.read_csv(file, encoding='cp949', encoding_errors='ignore')
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_2368\411496607.py:6: DtypeWarning: Columns (36,41,42) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file, encoding='cp949', encoding_errors='ignore')

# %%
df.head()
# Out:
#    개방자치단체코드                    관리번호       인허가일자  인허가취소일자  영업상태코드  영업상태명  \
# 0   3000000  3000000-104-2019-00037  2019-02-14      NaN       1  영업/정상
# 1   3000000  3000000-104-2019-00038  2019-02-14      NaN       1  영업/정상
# 2   3000000  3000000-104-2019-00039  2019-02-14      NaN       1  영업/정상
# 3   3000000  3000000-104-2019-00068  2019-03-28      NaN       1  영업/정상
# 4   3000000  3000000-104-2019-00042  2019-02-22      NaN       1  영업/정상
#
#    상세영업상태코드 상세영업상태명 폐업일자  휴업시작일자  ...  공장판매직종업원수  공장생산직종업원수 건물소유구분명  보증액  월세액  \
# 0         1      영업  NaN     NaN  ...        0.0        0.0     NaN  0.0  0.0
# 1         1      영업  NaN     NaN  ...        0.0        0.0     NaN  0.0  0.0
# 2         1      영업  NaN     NaN  ...        0.0        0.0     NaN  0.0  0.0
# 3         1      영업  NaN     NaN  ...        0.0        0.0     NaN  0.0  0.0
# 4         1      영업  NaN     NaN  ...        0.0        0.0     NaN  0.0  0.0
#
#   다중이용업소여부  시설총규모  전통업소지정번호 전통업소주된음식 홈페이지
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 143896 entries, 0 to 143895
# Data columns (total 44 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   개방자치단체코드   143896 non-null  int64
#  1   관리번호       143896 non-null  object
#  2   인허가일자      143896 non-null  object
#  3   인허가취소일자    0 non-null       float64
#  4   영업상태코드     143896 non-null  int64
#  5   영업상태명      143896 non-null  object
#  6   상세영업상태코드   143896 non-null  int64
#  7   상세영업상태명    143896 non-null  object
#  8   폐업일자       107095 non-null  object
#  9   휴업시작일자     0 non-null       float64
#  10  휴업종료일자     0 non-null       float64
#  11  재개업일자      0 non-null       float64
#  12  전화번호       58335 non-null   object
#  13  소재지면적      131802 non-null  float64
#  14  소재지우편번호    143709 non-null  object
#  15  지번주소       143712 non-null  object
#  16  도로명주소      102297 non-null  object
#  17  도로명우편번호    101457 non-null  float64
#  18  사업장명       143896 non-null  object
# ...

# %%
df.isna().sum()
# Out:
# 개방자치단체코드          0
# 관리번호              0
# 인허가일자             0
# 인허가취소일자      143896
# 영업상태코드            0
# 영업상태명             0
# 상세영업상태코드          0
# 상세영업상태명           0
# 폐업일자          36801
# 휴업시작일자       143896
# 휴업종료일자       143896
# 재개업일자        143896
# 전화번호          85561
# 소재지면적         12094
# 소재지우편번호         187
# 지번주소            184
# 도로명주소         41599
# 도로명우편번호       42439
# 사업장명              0
# 최종수정일자            0
# 데이터갱신구분           0
# 데이터갱신일자           0
# 업태구분명             0
# 좌표정보(X)        6134
# 좌표정보(Y)        6134
# 위생업태명           338
# 남성종사자수         6030
# 여성종사자수         6021
# 영업장주변구분명     107813
# 등급구분명        109315
# 급수시설구분명       88433
# 총인원            8651
# 본사종업원수         8644
# 공장사무직종업원수      8644
# 공장판매직종업원수      8644
# 공장생산직종업원수      8644
# 건물소유구분명      143892
# 보증액            8644
# 월세액            8644
# 다중이용업소여부        338
# 시설총규모           338
# 전통업소지정번호     143828
# 전통업소주된음식     143891
# 홈페이지         143896
# dtype: int64

# %%
df.loc[0]
# Out:
# 개방자치단체코드                                          3000000
# 관리번호                               3000000-104-2019-00037
# 인허가일자                                          2019-02-14
# 인허가취소일자                                               NaN
# 영업상태코드                                                  1
# 영업상태명                                               영업/정상
# 상세영업상태코드                                                1
# 상세영업상태명                                                영업
# 폐업일자                                                  NaN
# 휴업시작일자                                                NaN
# 휴업종료일자                                                NaN
# 재개업일자                                                 NaN
# 전화번호                                                  NaN
# 소재지면적                                               28.41
# 소재지우편번호                                           110-813
# 지번주소                           서울특별시 종로구 무악동 46 경희궁 롯데캐슬
# ...

# %%
cols = ["인허가일자","폐업일자","지번주소","영업상태명","사업장명","업태구분명","상세영업상태명"]
df2 = df[cols]
df2
# Out:
#              인허가일자        폐업일자                                    지번주소  영업상태명  \
# 0       2019-02-14         NaN              서울특별시 종로구 무악동 46 경희궁 롯데캐슬   영업/정상
# 1       2019-02-14         NaN               서울특별시 종로구 수송동 110 연합뉴스빌딩   영업/정상
# 2       2019-02-14         NaN           서울특별시 종로구 숭인동 178-89번지 1층 일부   영업/정상
# 3       2019-03-28         NaN                       서울특별시 종로구 통의동 47   영업/정상
# 4       2019-02-22         NaN                       서울특별시 종로구 익선동 42   영업/정상
# ...            ...         ...                                     ...    ...
# 143891  2000-08-16  2026-04-10             서울특별시 중구 신당동 366-79 그랜드마트1층     폐업
# 143892  2026-03-27  2026-04-10                서울특별시 서초구 반포동 19-3 센트럴시티     폐업
# 143893  2026-03-19  2026-04-10                   서울특별시 강남구 삼성동 159 코엑스     폐업
# 143894  2026-03-10  2026-04-11  서울특별시 서초구 서초동 1498-5 마제스타시티, 힐스테이트 서리풀     폐업
# 143895  2026-03-05  2026-04-11               서울특별시 서초구 잠원동 70-2 뉴코아백화점     폐업
#
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 143896 entries, 0 to 143895
# Data columns (total 7 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   인허가일자    143896 non-null  object
#  1   폐업일자     107095 non-null  object
#  2   지번주소     143712 non-null  object
#  3   영업상태명    143896 non-null  object
#  4   사업장명     143896 non-null  object
#  5   업태구분명    143896 non-null  object
#  6   상세영업상태명  143896 non-null  object
# dtypes: object(7)
# memory usage: 7.7+ MB

# %%
df2['인허가연도'] = df2['인허가일자'].str[:4]
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_2368\863764435.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['인허가연도'] = df2['인허가일자'].str[:4]

# %%
df2['인허가연도'].sort_values()
# Out:
# 82121     1900
# 131948    1904
# 107366    1904
# 38351     1909
# 91076     1913
#           ...
# 86990     2026
# 86991     2026
# 86995     2026
# 129248    2026
# 143895    2026
# Name: 인허가연도, Length: 143896, dtype: object

# %%
df2['인허가연도'] = pd.to_numeric(df2['인허가연도'])
df2.query('인허가연도 < 1910')
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_2368\797569420.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['인허가연도'] = pd.to_numeric(df2['인허가연도'])
#              인허가일자        폐업일자                     지번주소 영업상태명       사업장명  \
# 38351   1909-03-12  1994-06-20   서울특별시 성북구 동선동2가 165번지     폐업  뺑뜨비성신여대분점
# 82121   1900-08-12  1995-08-21  서울특별시 구로구 구로동 716-10번지     폐업         청자
# 107366  1904-08-08  1994-07-05  서울특별시 서초구 방배동 777-20번지     폐업        피터팬
# 131948  1904-08-08  1993-12-31   서울특별시 송파구 잠실동 228-9번지     폐업      코리아세븐
#
#         업태구분명 상세영업상태명  인허가연도
# 38351     과자점      폐업   1909
# 82121      다방      폐업   1900
# 107366     다방      폐업   1904
# 131948  패스트푸드      폐업   1904

# %%
df2['업태구분명'].unique()
# Out:
# array(['기타 휴게음식점', '커피숍', '편의점', '일반조리판매', '다방', '푸드트럭', '전통찻집', '아이스크림',
#        '패스트푸드', '과자점', '떡카페', '단란주점', '철도역구내', '호프/통닭', '극장', '백화점',
#        '관광호텔', '키즈카페', '고속도로', '유원지', '기타', '김밥(도시락)', '룸살롱', '공항', '한식'],
#       dtype=object)

# %%
df2_tea = df2[df2['업태구분명'] == '전통찻집']
df2_tea
# Out:
#              인허가일자        폐업일자                                 지번주소  영업상태명  \
# 86      2023-09-11         NaN             서울특별시 종로구 관훈동 186 관훈겟앤쇼   영업/정상
# 87      2023-08-03         NaN              서울특별시 종로구 관훈동 8-5 인사유리   영업/정상
# 94      2019-02-13         NaN          서울특별시 종로구 관훈동 21번지 인사아트플라자   영업/정상
# 103     2019-07-08         NaN                   서울특별시 종로구 공평동 9번지   영업/정상
# 157     2023-06-16         NaN                서울특별시 종로구 팔판동 115-30   영업/정상
# ...            ...         ...                                  ...    ...
# 143109  2018-03-20  2018-12-20        서울특별시 강동구 강일동 675-3번지 임페리얼타워      폐업
# 143205  2017-11-20  2019-07-04               서울특별시 강동구 명일동 328-5번지      폐업
# 143725  2021-12-22         NaN                  서울특별시 종로구 삼청동 35-88  영업/정상
# 143756  2026-04-09         NaN                  서울특별시 노원구 공릉동 661-7  영업/정상
# 143890  2009-05-20         NaN  서울특별시 종로구 사직동 9 풍림스페이스본 201동 107-A호  영업/정상
#
#                                사업장명 업태구분명 상세영업상태명  인허가연도
# ...

# %%
df2['인허가연도'].drop_duplicates().sort_values().tail(20)
# Out:
# 200     2007
# 362     2008
# 107     2009
# 89      2010
# 463     2011
# 227     2012
# 743     2013
# 482     2014
# 497     2015
# 347     2016
# 126     2017
# 19      2018
# 0       2019
# 996     2020
# 1110    2021
# 5       2022
# 29      2023
# 95      2024
# 1086    2025
# 44      2026
# Name: 인허가연도, dtype: int64

# %%
df2.query('인허가연도 == 2025')
# Out:
#              인허가일자        폐업일자                               지번주소  영업상태명  \
# 1086    2025-12-29         NaN      서울특별시 종로구 계동 140-2 현대빌딩 지하2층   영업/정상
# 1087    2025-12-29         NaN                서울특별시 종로구 견지동 68-1   영업/정상
# 1096    2025-12-30         NaN             서울특별시 종로구 와룡동 59 서진빌딩   영업/정상
# 1101    2025-01-05         NaN      서울특별시 종로구 평동 222 NH농협타워 지하2층   영업/정상
# 1102    2025-12-31         NaN                  서울특별시 종로구 체부동 38   영업/정상
# ...            ...         ...                                ...    ...
# 143863  2025-07-14  2026-04-10               서울특별시 도봉구 방학동 632-72     폐업
# 143864  2025-06-05  2026-04-10  서울특별시 마포구 공덕동 456 한국사회복지회관 르네상스타워     폐업
# 143865  2025-04-09         NaN            서울특별시 중구 소공동 1 롯데백화점 본점  영업/정상
# 143866  2025-04-07         NaN                서울특별시 광진구 화양동 15-54  영업/정상
# 143867  2025-03-31         NaN        서울특별시 강남구 삼성동 8-2 브라운스톤 레전드  영업/정상
#
#                             사업장명     업태구분명 상세영업상태명  인허가연도
# ...

# %%
df2['인허가월'] = df2 ['인허가일자'].str.split('-').str[1]
df2['인허가월'] = pd.to_numeric(df2['인허가월'])
# 2025년 인허가월별 개업가게수
df2.query('인허가연도 == 2025')['인허가월'].value_counts().sort_index().plot()
# df2['인허가월'].count()
# df2.head()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_2368\711776446.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['인허가월'] = df2 ['인허가일자'].str.split('-').str[1]
# C:\Users\User\AppData\Local\Temp\ipykernel_2368\711776446.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['인허가월'] = pd.to_numeric(df2['인허가월'])
# <Axes: xlabel='인허가월'>
