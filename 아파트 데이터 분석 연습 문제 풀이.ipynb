# %%
import pandas as pd
df = pd.read_excel('./data/apt_seoul.xlsx',skiprows=12, thousands=",")
# Out:
# C:\Users\User\anaconda3\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
# 불편한 칼럼이름 변경 - 전용면적(㎡)	,거래금액(만원)
# df.rename() 바뀐 복사본 반환 . 원본이 안바뀜
# 1. df = df.rename(....)
# 2. df.rename(...  ,inplace=True)
df.rename( 
    columns={
        "전용면적(㎡)":"전용면적", 
        "거래금액(만원)":"거래금액"
    }, inplace=True
)
# 시군구를 구,동으로 분리저장
df['구'] = df['시군구'].str.split().str[1]
df['동'] = df['시군구'].str.split().str[2]
# 전용면적 -> 평
df['평'] = df['전용면적'] / 3.3
# 평 -> 평형
def to_ph(x):
    if x < 10: return '10평이하'
    if x < 20: return '10평대'
    if x < 30: return '20평대'
    if x < 40: return '30평대'
    return '40평이상'
df['평형'] = df['평'].apply(to_ph)
# 거래취소된 행 삭제(정상거래된 행)
df = df.query(' 해제사유발생일 == "-" ')
# 가격에 영향없는 칼럼 삭제
df.drop(columns=['NO', '번지', '본번', '부번','매수자', '매도자', '도로명', '해제사유발생일', '거래유형', '중개사소재지',
       '등기일자', '주택유형',], inplace=True)
# 거래금액을 억단위로 변환
df['거래금액'] = df['거래금액'] / 10000
# 계약년월+계약일 -> 요일
df['계약일자'] = pd.to_datetime(
    df['계약년월'].astype(str) + df['계약일'].astype(str).str.zfill(2),
    format='%Y%m%d'
)

df['계약요일'] = df['계약일자'].dt.day_name().map({
    'Monday': '월', 'Tuesday': '화', 'Wednesday': '수',
    'Thursday': '목', 'Friday': '금', 'Saturday': '토', 'Sunday': '일'
})

# %% [markdown]
# ### 위 아파트 데이터 로딩후 전처리한 결과를 바탕으로 아래 문제를 풀어보세요
# ### 위 코드를 먼저 실행하세요

# %% [markdown]
# ## 🟢 기본 탐색
#
# 1. 데이터의 행과 열의 개수를 구하시오.

# %%
df.shape
# Out:
# (71669, 14)

# %% [markdown]
# 2. 각 컬럼의 데이터 타입을 확인하시오.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 71669 entries, 0 to 76665
# Data columns (total 14 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   시군구     71669 non-null  object
#  1   단지명     71669 non-null  object
#  2   전용면적    71669 non-null  float64
#  3   계약년월    71669 non-null  int64
#  4   계약일     71669 non-null  int64
#  5   거래금액    71669 non-null  float64
#  6   동       71669 non-null  object
#  7   층       71669 non-null  int64
#  8   건축년도    71669 non-null  int64
#  9   구       71669 non-null  object
#  10  평       71669 non-null  float64
#  11  평형      71669 non-null  object
#  12  계약일자    71669 non-null  datetime64[ns]
#  13  계약요일    71669 non-null  object
# dtypes: datetime64[ns](1), float64(3), int64(4), object(6)
# memory usage: 8.2+ MB

# %% [markdown]
# 3. 수치형 데이터의 기초 통계량과 문자형 데이터의 기초 통계량을 구하시오.

# %%
display(df.describe()) #수치형 데이터의 기초 통계량
display(df.describe(include="object")) #문자형 데이터의 기초 통계량
# Out:
#               전용면적           계약년월           계약일          거래금액             층  \
# count  71669.00000   71669.000000  71669.000000  71669.000000  71669.000000
# mean      75.21771  202527.183343     16.408029     11.944678      9.562977
# min       12.01000  202504.000000      1.000000      0.650000     -2.000000
# 25%       59.74790  202506.000000     10.000000      6.780000      5.000000
# 50%       79.94500  202509.000000     17.000000      9.800000      9.000000
# 75%       84.96000  202512.000000     24.000000     14.550000     13.000000
# max      317.36000  202604.000000     31.000000    290.000000     66.000000
# std       27.33249      38.121455      8.505771      8.788101      6.358990
#
#                건축년도             평                           계약일자
# count  71669.000000  71669.000000                          71669
# mean    2003.209923     22.793246  2025-09-17 12:28:11.978400768
# min     1961.000000      3.639394            2025-04-07 00:00:00
# 25%     1996.000000     18.105424            2025-06-18 00:00:00
# 50%     2003.000000     24.225758            2025-09-19 00:00:00
# 75%     2012.000000     25.745455            2025-12-11 00:00:00
# max     2025.000000     96.169697            2026-04-04 00:00:00
# std       11.287104      8.282573                            NaN
#                   시군구    단지명      동      구     평형   계약요일
# count           71669  71669  71669  71669  71669  71669
# unique            320   4894    318     25      5      7
# top     서울특별시 노원구 상계동     현대    상계동    노원구   20평대      토
# freq             2411    713   2411   6153  30229  16718

# %% [markdown]
# 4. 각 칼럼별 결측치갯수를 출력하시오.

# %%
df.isnull().sum()
# Out:
# 시군구     0
# 단지명     0
# 전용면적    0
# 계약년월    0
# 계약일     0
# 거래금액    0
# 동       0
# 층       0
# 건축년도    0
# 구       0
# 평       0
# 평형      0
# 계약일자    0
# 계약요일    0
# dtype: int64

# %% [markdown]
# ## 🟡 단일 변수 분석
#
# 5. 전체 거래금액의 평균, 최대값, 최소값을 구하시오.

# %%
df['거래금액'].agg(["mean",'max','min'])
# Out:
# mean     11.944678
# max     290.000000
# min       0.650000
# Name: 거래금액, dtype: float64

# %% [markdown]
# 6. 각 구별 거래 건수를 구하시오.

# %%
df['구'].value_counts()
# Out:
# 구
# 노원구     6153
# 강동구     4502
# 강서구     4448
# 성북구     4325
# 송파구     4163
# 영등포구    3918
# 동대문구    3622
# 구로구     3580
# 성동구     3349
# 동작구     3347
# 마포구     3229
# 양천구     3212
# 은평구     3048
# 서대문구    3046
# 강남구     2690
# 관악구     2323
# 중랑구     2133
# 도봉구     1942
# 서초구     1894
# 광진구     1666
# 강북구     1302
# 용산구     1147
# 중구      1075
# 금천구      954
# 종로구      601
# Name: count, dtype: int64

# %% [markdown]
# 7. 평형별 거래 건수를 구하시오.

# %%
df['평형'].value_counts()
# Out:
# 평형
# 20평대     30229
# 10평대     28556
# 30평대      7219
# 10평이하     3171
# 40평이상     2494
# Name: count, dtype: int64

# %% [markdown]
# 8. 층의 분포를 박스플롯과 히스트그램으로 시각화하시오.

# %%
import matplotlib.pyplot as plt

plt.rc('font',family='Malgun Gothic')

df['층'].plot.box()
plt.show()

df['층'].plot.hist(bins=30)
plt.show()

# %% [markdown]
# ## 🟠 그룹 분석
#
# 9. 구별 거래금액의 평균, 최대값, 최소값을 구하시오.

# %%
df.groupby('구')['거래금액'].agg(['mean','max','min'])
# Out:
#            mean     max     min
# 구
# 강남구   28.351920  190.00  1.3500
# 강동구   12.682820   33.00  0.7300
# 강북구    6.588776   12.70  0.7500
# 강서구    8.877549   23.00  0.7100
# 관악구    8.337241   17.00  0.8000
# 광진구   14.191279   39.00  1.1500
# 구로구    7.135536   21.00  0.6950
# 금천구    6.419462   14.05  0.8000
# 노원구    6.348460   16.00  0.8000
# 도봉구    5.600070   14.15  0.6500
# 동대문구   9.276496   21.90  0.8200
# 동작구   13.177472   35.00  1.1000
# 마포구   14.777156   40.00  1.0000
# 서대문구  10.429531   24.45  1.1200
# 서초구   25.226896   96.00  1.9800
# 성동구   16.326495  290.00  1.3000
# 성북구    8.770942   20.90  1.0500
# 송파구   18.683833   67.00  1.5000
# 양천구   13.296219   43.50  1.2000
# 영등포구  12.667759   83.00  0.8321
# 용산구   20.111613  167.00  1.5000
# 은평구    8.421117   18.65  0.9500
# 종로구   11.675781   74.00  0.8800
# 중구    11.818697   45.30  1.2400
# 중랑구    6.496701   18.00  0.8600

# %% [markdown]
# 10.    계절별 거래금액의 평균, 최대값, 최소값을 구하시오.

# %%
display(df.head(1))
def to_season(x):
    x = x%100
    if x in[12,1,2]: return '겨울'
    if x in[3,4,5]: return '봄'
    if x in[6,7,8]: return '여름'
    return '가을'
df['계절'] = df['계약년월'].apply(to_season)
df.groupby('계절')['거래금액'].agg(['mean','max','min'])
df['계절'].value_counts().plot.barh()
# Out:
#              시군구     단지명     전용면적    계약년월  계약일  거래금액    동   층  건축년도    구  \
# 0  서울특별시 은평구 수색동  DMC 진흥  78.2853  202604    4  7.75  수색동  15  2003  은평구
#
#            평    평형       계약일자 계약요일 계절
# 0  23.722818  20평대 2026-04-04    토  봄
# <Axes: ylabel='계절'>

# %% [markdown]
# 11. 구별 평형별 평균 거래금액을 구하시오.

# %%
df.groupby('구')['거래금액'].mean()
# Out:
# 구
# 강남구     28.351920
# 강동구     12.682820
# 강북구      6.588776
# 강서구      8.877549
# 관악구      8.337241
# 광진구     14.191279
# 구로구      7.135536
# 금천구      6.419462
# 노원구      6.348460
# 도봉구      5.600070
# 동대문구     9.276496
# 동작구     13.177472
# 마포구     14.777156
# 서대문구    10.429531
# 서초구     25.226896
# 성동구     16.326495
# 성북구      8.770942
# 송파구     18.683833
# 양천구     13.296219
# 영등포구    12.667759
# 용산구     20.111613
# 은평구      8.421117
# 종로구     11.675781
# 중구      11.818697
# 중랑구      6.496701
# Name: 거래금액, dtype: float64

# %% [markdown]
# ## 🔵 시각화
#
# 12. 구별 평균 거래금액을 막대그래프로 표현하시오.

# %%
df.groupby('구')['거래금액'].mean().plot.bar(rot=45)
plt.show()

# %% [markdown]
# 13. 전용면적과 거래금액의 관계를 산점도로 표현하시오.

# %%
df.plot.scatter(x='전용면적', y='거래금액')
plt.show()

# %% [markdown]
# 14. 평형별 거래금액 분포를 박스플롯으로 표현하시오.

# %%
import seaborn as sns
sns.boxplot(data=df, x='평형', y='거래금액')
# Out:
# <Axes: xlabel='평형', ylabel='거래금액'>

# %% [markdown]
# ## 🔴 시간 분석
#
# 15. 요일별 거래 건수를 구하시오.

# %%
df['계약요일'].value_counts()
# Out:
# 계약요일
# 토    16718
# 금    12436
# 수    10496
# 목     9861
# 화     9722
# 월     8803
# 일     3633
# Name: count, dtype: int64

# %% [markdown]
# 16. 요일별 평균 거래금액을 구하시오.

# %%
df.groupby('계약요일')['거래금액'].mean()
# Out:
# 계약요일
# 금    12.394864
# 목    11.947082
# 수    11.822990
# 월    11.808413
# 일    11.606726
# 토    11.727544
# 화    12.120810
# Name: 거래금액, dtype: float64

# %% [markdown]
# 17. 날짜별 거래 건수 추이를 확인하시오.

# %%
print(df.groupby('계약일자').size().sort_index())
df.groupby('계약일자').size().sort_index().plot()
# Out:
# 계약일자
# 2025-04-07    147
# 2025-04-08    162
# 2025-04-09    131
# 2025-04-10    157
# 2025-04-11    189
#              ...
# 2026-03-31     36
# 2026-04-01     39
# 2026-04-02     20
# 2026-04-03      5
# 2026-04-04      1
# Length: 363, dtype: int64
# <Axes: xlabel='계약일자'>

# %% [markdown]
# ## 🟣 심화 분석
#
# 18. 거래 건수가 가장 많은 구 TOP 5를 구하시오.

# %%
df['구'].value_counts().head(5)
# Out:
# 구
# 노원구    6153
# 강동구    4502
# 강서구    4448
# 성북구    4325
# 송파구    4163
# Name: count, dtype: int64

# %% [markdown]
# 19. 거래금액이 가장 높은 상위 10건을 조회하시오.

# %%
df.sort_values(by='거래금액', ascending=False).head(10)
# Out:
#                    시군구                          단지명      전용면적    계약년월  계약일  \
# 60199  서울특별시 성동구 성수동1가                    아크로서울포레스트  273.9280  202506   11
# 50587    서울특별시 강남구 청담동                        PH129  273.9600  202507    1
# 64311  서울특별시 성동구 성수동1가                    아크로서울포레스트  198.2190  202505   29
# 45639    서울특별시 용산구 한남동                        나인원한남  244.3478  202508    5
# 45341    서울특별시 용산구 한남동                        나인원한남  244.3478  202508    8
# 707      서울특별시 용산구 한남동                        나인원한남  244.3478  202603   23
# 18149    서울특별시 강남구 청담동                        PH129  273.9600  202512   12
# 13518    서울특별시 용산구 한남동                        나인원한남  244.3478  202601   12
# 43995   서울특별시 강남구 압구정동  현대1차(12,13,21,22,31,32,33동)  196.2100  202508   18
# 73255   서울특별시 강남구 압구정동           현대7차(73~77,82,85동)  245.2000  202504   25
#
#         거래금액      동   층  건축년도    구          평     평형       계약일자 계약요일  계절
# 60199  290.0  성수동1가  47  2020  성동구  83.008485  40평이상 2025-06-11    수  여름
# 50587  190.0    청담동  12  2020  강남구  83.018182  40평이상 2025-07-01    화  여름
# 64311  187.0  성수동1가  46  2020  성동구  60.066364  40평이상 2025-05-29    목   봄
# 45639  167.0    한남동   5  2019  용산구  74.044788  40평이상 2025-08-05    화  여름
# 45341  160.0    한남동   4  2019  용산구  74.044788  40평이상 2025-08-08    금  여름
# 707    156.5    한남동   4  2019  용산구  74.044788  40평이상 2026-03-23    월   봄
# 18149  155.0    청담동  10  2020  강남구  83.018182  40평이상 2025-12-12    금  겨울
# 13518  140.4    한남동   5  2019  용산구  74.044788  40평이상 2026-01-12    월  겨울
# 43995  130.5   압구정동   6  1976  강남구  59.457576  40평이상 2025-08-18    월  여름
# 73255  130.5   압구정동   8  1979  강남구  74.303030  40평이상 2025-04-25    금   봄

# %% [markdown]
# 20. 강남3구+용산구와 그외지역의 거래건수,평균거래가격 를 출력하세요.
